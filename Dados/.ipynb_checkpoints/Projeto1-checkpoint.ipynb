# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Gabriel Pizzighini Salvador
# ___

# %% [markdown]
# ## A comunicação na região do Parána

# %% [markdown]
# ___
# ## Introdução
#
# o objetivo desta pesquisa é fazer uma comparaçao em que quanto o uso da internet influencia na renda da população do Parána, levando-se em base os dados do IBGE das PNADs dos anos 2013, 2014 e 2015.

# %% [markdown]
# ### A internet influencia na renda das pessoas do estado do Parána, ao longo de tres anos?

# %% [markdown]
# ___
# ## Análise e Resultados

# %% [markdown]
# #### importção de bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import os
#dt = pd.DataFrame

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Faculdade\Documents\2º Semestre\Ciência dos Dados\GitHub\CD-Projeto-1\Dados

# %% [markdown]
# #### Incerção das tabelas filtradas para os anos de 2015, 2014 e 2013 respectivamente:

# %% [markdown]
# ### 2015

# %%
#Indices de 2015 com limpeza de dados 
data = pd.read_csv('DOM2015.csv',sep=',')
data_resume_2015 = data.loc[:,['UF','V02270','V02271','V02322','V4614','V4621','V4622']]
data_resume_2015 = pd.DataFrame(data_resume_2015[data_resume_2015["UF"].isin(["41"])])
data_resume_2015['Num.Televisores'] = data_resume_2015['V02270'] + data_resume_2015['V02271']
del data_resume_2015['V02270']
del data_resume_2015['V02271']
data_resume_2015 = data_resume_2015.rename(columns = {'V02322' : 'Internet','V4614':'Rend.mens.Domiciliar','V4621':'Ren.mens.percapta','V4622':'Faixa.Rend.mens.percapta'})
data_resume_2015['Internet'] = data_resume_2015['Internet'].astype('category')
data_resume_2015['Faixa.Rend.mens.percapta'] = data_resume_2015['Faixa.Rend.mens.percapta'].astype('category')
data_resume_2015['UF'] = data_resume_2015['UF'].astype('category')
data_resume_2015['Rend.mens.Domiciliar'] =data_resume_2015['Rend.mens.Domiciliar'].astype('float')
data_resume_2015.Internet.cat.categories = (['Sim', 'Nao'])
data_resume_2015.UF.cat.categories = (['PR'])
data_resume_2015 = data_resume_2015[data_resume_2015['Rend.mens.Domiciliar']!=999999999999.0]
data_resume_2015 = data_resume_2015[data_resume_2015['Faixa.Rend.mens.percapta']!=999999999999.0]
data_resume_2015 = data_resume_2015[pd.notnull(data_resume_2015['Internet'])&pd.notnull(data_resume_2015['Rend.mens.Domiciliar'])&pd.notnull(data_resume_2015['Ren.mens.percapta'])&pd.notnull(data_resume_2015['Num.Televisores'])]
#pd.DataFrame(data_resume_2015)
#----------------------------------------------------------------
baixa = 441
media = 1019
alta = 2480
data_resume_2015.loc[data_resume_2015['Ren.mens.percapta'] < baixa, "Classe"] = "baixa"
data_resume_2015.loc[(data_resume_2015['Ren.mens.percapta'] > baixa)&(data_resume_2015['Ren.mens.percapta']<media), "Classe"] = "média baixa"
data_resume_2015.loc[(data_resume_2015['Ren.mens.percapta'] > media)&(data_resume_2015['Ren.mens.percapta']<alta),'Classe'] = 'média'
data_resume_2015.loc[data_resume_2015['Ren.mens.percapta'] > alta, "Classe"] = "alta"
#----------------------------------------------------------------
pd.DataFrame(data_resume_2015)
# Out:
#         UF Internet  Rend.mens.Domiciliar  Ren.mens.percapta  \
# 110422  PR      Sim                 900.0              180.0
# 110423  PR      Nao                2620.0             1310.0
# 110424  PR      Sim                1588.0              794.0
# 110425  PR      Nao                3076.0             1025.0
# 110426  PR      Sim                1708.0              569.0
# 110427  PR      Sim                3100.0              775.0
# 110428  PR      Sim                1000.0              500.0
# 110429  PR      Sim                3538.0              707.0
# 110430  PR      Nao                1738.0              579.0
# 110431  PR      Sim                3200.0              640.0
# 110432  PR      Sim                6400.0             1280.0
# 110433  PR      Sim                1200.0              600.0
# 110434  PR      Nao                 788.0              262.0
# 110435  PR      Sim                4200.0             1400.0
# 110436  PR      Sim                2000.0              666.0
# 110437  PR      Sim                3576.0             1192.0
# 110438  PR      Sim                2130.0              532.0
# 110439  PR      Nao                1500.0              500.0
# 110440  PR      Nao                2400.0              600.0
# 110441  PR      Sim                 788.0              262.0
# 110442  PR      Nao                1588.0              794.0
# 110443  PR      Sim                1576.0             1576.0
# 110444  PR      Sim                2800.0              700.0
# 110445  PR      Nao                 788.0              788.0
# 110446  PR      Sim               12800.0             1828.0
# 110447  PR      Sim                2600.0              650.0
# 110448  PR      Nao                1100.0             1100.0
# 110449  PR      Sim                2600.0              520.0
# 110450  PR      Sim                2364.0             1182.0
# 110451  PR      Sim                5900.0             2950.0
# ...     ..      ...                   ...                ...
# 118048  PR      Sim                4350.0              870.0
# 118049  PR      Sim                 900.0              900.0
# 118050  PR      Nao                1600.0              400.0
# 118051  PR      Sim                 900.0              450.0
# 118052  PR      Sim                4800.0             1600.0
# 118053  PR      Nao                2000.0             2000.0
# 118054  PR      Nao                1000.0              500.0
# 118056  PR      Sim                 800.0              800.0
# 118057  PR      Nao                1200.0             1200.0
# 118058  PR      Sim                7500.0             1875.0
# 118061  PR      Nao                1000.0              333.0
# 118062  PR      Nao                1680.0              420.0
# 118063  PR      Nao                 790.0              790.0
# 118064  PR      Nao                 788.0              788.0
# 118065  PR      Sim                3200.0              800.0
# 118066  PR      Nao                1050.0              262.0
# 118067  PR      Sim                3000.0              750.0
# 118068  PR      Sim                 900.0              225.0
# 118069  PR      Sim                2000.0              666.0
# 118071  PR      Sim                2400.0             1200.0
# 118073  PR      Nao                2254.0              450.0
# 118075  PR      Sim                2300.0             1150.0
# 118076  PR      Sim                4040.0             1346.0
# 118077  PR      Sim                2184.0             1092.0
# 118079  PR      Sim                2100.0              700.0
# 118080  PR      Sim                2700.0              675.0
# 118081  PR      Sim                2950.0              983.0
# 118083  PR      Sim                2700.0              540.0
# 118085  PR      Nao                3100.0              620.0
# 118086  PR      Sim                3400.0             1700.0
#
#        Faixa.Rend.mens.percapta  Num.Televisores       Classe
# 110422                      1.0              1.0        baixa
# 110423                      4.0              2.0        média
# 110424                      4.0              2.0  média baixa
# 110425                      4.0              1.0        média
# 110426                      3.0              2.0  média baixa
# 110427                      3.0              2.0  média baixa
# 110428                      3.0              1.0  média baixa
# 110429                      3.0              2.0  média baixa
# 110430                      3.0              1.0  média baixa
# 110431                      3.0              1.0  média baixa
# 110432                      4.0              3.0        média
# 110433                      3.0              1.0  média baixa
# 110434                      2.0              2.0        baixa
# 110435                      4.0              1.0        média
# 110436                      3.0              2.0  média baixa
# 110437                      4.0              3.0        média
# 110438                      3.0              2.0  média baixa
# 110439                      3.0              1.0  média baixa
# 110440                      3.0              2.0  média baixa
# 110441                      2.0              2.0        baixa
# 110442                      4.0              1.0  média baixa
# 110443                      4.0              1.0        média
# 110444                      3.0              2.0  média baixa
# 110445                      3.0              2.0  média baixa
# 110446                      5.0              4.0        média
# 110447                      3.0              2.0  média baixa
# 110448                      4.0              1.0        média
# 110449                      3.0              2.0  média baixa
# 110450                      4.0              2.0        média
# 110451                      6.0              1.0         alta
# ...                         ...              ...          ...
# 118048                      4.0              3.0  média baixa
# 118049                      4.0              1.0  média baixa
# 118050                      3.0              2.0        baixa
# 118051                      3.0              2.0  média baixa
# 118052                      5.0              1.0        média
# 118053                      5.0              1.0        média
# 118054                      3.0              2.0  média baixa
# 118056                      4.0              3.0  média baixa
# 118057                      4.0              2.0        média
# 118058                      5.0              1.0        média
# 118061                      2.0              2.0        baixa
# 118062                      3.0              3.0        baixa
# 118063                      4.0              1.0  média baixa
# 118064                      3.0              1.0  média baixa
# 118065                      4.0              1.0  média baixa
# 118066                      2.0              2.0        baixa
# 118067                      3.0              2.0  média baixa
# 118068                      2.0              3.0        baixa
# 118069                      3.0              1.0  média baixa
# 118071                      4.0              1.0        média
# 118073                      3.0              2.0  média baixa
# 118075                      4.0              2.0        média
# 118076                      4.0              2.0        média
# 118077                      4.0              1.0        média
# 118079                      3.0              1.0  média baixa
# 118080                      3.0              2.0  média baixa
# 118081                      4.0              1.0  média baixa
# 118083                      3.0              1.0  média baixa
# 118085                      3.0              1.0  média baixa
# 118086                      5.0              1.0        média
#
# [6223 rows x 7 columns]

# %% [markdown]
# ___
# ### 2014

# %%
#Indices de 2014 com limpeza de Dados 
data = pd.read_csv('DOM2014.csv',sep=',')
data_resume_2014 = data.loc[:,['UF','V02270','V02271','V02322','V4614','V4621','V4622']]
data_resume_2014 = pd.DataFrame(data_resume_2014[data_resume_2014["UF"].isin(["41"])])
data_resume_2014['Num.Televisores'] = data_resume_2014['V02270'] + data_resume_2014['V02271']
del data_resume_2014['V02270']
del data_resume_2014['V02271']
data_resume_2014 = data_resume_2014.rename(columns = {'V02322' : 'Internet','V4614':'Rend.mens.Domiciliar','V4621':'Ren.mens.percapta','V4622':'Faixa.Rend.mens.percapta'})
data_resume_2014['Internet'] = data_resume_2014['Internet'].astype('category')
data_resume_2014['UF'] = data_resume_2014['UF'].astype('category')
data_resume_2014['Rend.mens.Domiciliar'] =data_resume_2014['Rend.mens.Domiciliar'].astype('float')
data_resume_2014['Ren.mens.percapta'] = data_resume_2014['Ren.mens.percapta'].astype('float')
data_resume_2014.Internet.cat.categories = (['Sim', 'Nao'])
data_resume_2014.UF.cat.categories = (['PR'])
data_resume_2014 = data_resume_2014[data_resume_2014['Rend.mens.Domiciliar']!=999999999999.0]
data_resume_2015 = data_resume_2014[data_resume_2014['Faixa.Rend.mens.percapta']!=999999999999.0]
data_resume_2014 = data_resume_2014[pd.notnull(data_resume_2014['Internet'])&pd.notnull(data_resume_2014['Rend.mens.Domiciliar'])&pd.notnull(data_resume_2014['Ren.mens.percapta'])&pd.notnull(data_resume_2014['Num.Televisores'])]
#pd.DataFrame(data_resume_2014)
#----------------------------------------------------------------
baixa = 441
media = 1019
alta = 2480
data_resume_2014.loc[data_resume_2014['Ren.mens.percapta'] < baixa, "Classe"] = "baixa"
data_resume_2014.loc[(data_resume_2014['Ren.mens.percapta'] > baixa)&(data_resume_2014['Ren.mens.percapta']<media), "Classe"] = "média baixa"
data_resume_2014.loc[(data_resume_2014['Ren.mens.percapta'] > media)&(data_resume_2014['Ren.mens.percapta']<alta),'Classe'] = 'média'
data_resume_2014.loc[data_resume_2014['Ren.mens.percapta'] > alta, "Classe"] = "alta"
#----------------------------------------------------------------
pd.DataFrame(data_resume_2014)
# Out:
#         UF Internet  Rend.mens.Domiciliar  Ren.mens.percapta  \
# 110540  PR      Nao                1300.0              650.0
# 110541  PR      Sim                1300.0              433.0
# 110542  PR      Sim                2224.0              370.0
# 110543  PR      Nao                3000.0             3000.0
# 110544  PR      Nao                1626.0              406.0
# 110545  PR      Nao                1450.0              725.0
# 110546  PR      Nao                3400.0             1133.0
# 110547  PR      Nao                2500.0             1250.0
# 110548  PR      Nao                1000.0              333.0
# 110549  PR      Nao                1300.0             1300.0
# 110550  PR      Sim                1550.0              516.0
# 110551  PR      Nao                1448.0              724.0
# 110552  PR      Sim                2200.0             1100.0
# 110553  PR      Nao                1800.0             1800.0
# 110554  PR      Nao                1200.0             1200.0
# 110555  PR      Nao                2110.0              527.0
# 110556  PR      Nao                5000.0             5000.0
# 110557  PR      Sim                3500.0              875.0
# 110558  PR      Sim                9500.0             1900.0
# 110560  PR      Nao                1500.0             1500.0
# 110561  PR      Nao                2900.0             1450.0
# 110562  PR      Sim                3850.0             1925.0
# 110563  PR      Sim                9500.0             4750.0
# 110564  PR      Sim                2714.0              904.0
# 110565  PR      Sim                2000.0              500.0
# 110566  PR      Sim                2320.0             1160.0
# 110568  PR      Sim                4500.0             1500.0
# 110569  PR      Sim                2900.0              966.0
# 110571  PR      Nao                2124.0              708.0
# 110574  PR      Nao                3500.0              875.0
# ...     ..      ...                   ...                ...
# 118179  PR      Sim                1500.0              300.0
# 118180  PR      Nao                 724.0              724.0
# 118181  PR      Nao                3800.0              760.0
# 118182  PR      Nao                1574.0              787.0
# 118183  PR      Sim                3180.0             1060.0
# 118184  PR      Sim                2500.0              833.0
# 118185  PR      Sim                3974.0              993.0
# 118186  PR      Sim                1924.0              481.0
# 118187  PR      Nao                1448.0             1448.0
# 118188  PR      Nao                1924.0              962.0
# 118191  PR      Nao                 200.0              100.0
# 118192  PR      Nao                 900.0              450.0
# 118193  PR      Nao                1215.0              243.0
# 118196  PR      Sim                1000.0              333.0
# 118197  PR      Sim                3704.0              926.0
# 118198  PR      Nao                2050.0             1025.0
# 118199  PR      Sim                8800.0             2933.0
# 118200  PR      Nao                1924.0              641.0
# 118201  PR      Nao                5000.0             5000.0
# 118202  PR      Sim                2590.0              863.0
# 118203  PR      Nao                1448.0              724.0
# 118204  PR      Nao                1300.0             1300.0
# 118205  PR      Sim                3750.0             1250.0
# 118206  PR      Nao                1600.0              266.0
# 118207  PR      Sim                2024.0             1012.0
# 118208  PR      Nao                1448.0              724.0
# 118209  PR      Sim                3034.0              379.0
# 118210  PR      Nao                2934.0              733.0
# 118211  PR      Nao                 730.0              730.0
# 118212  PR      Sim                7000.0             1750.0
#
#         Faixa.Rend.mens.percapta  Num.Televisores       Classe
# 110540                       3.0              1.0  média baixa
# 110541                       3.0              2.0        baixa
# 110542                       3.0              3.0        baixa
# 110543                       6.0              1.0         alta
# 110544                       3.0              1.0        baixa
# 110545                       4.0              1.0  média baixa
# 110546                       4.0              1.0        média
# 110547                       4.0              1.0        média
# 110548                       2.0              1.0        baixa
# 110549                       4.0              1.0        média
# 110550                       3.0              1.0  média baixa
# 110551                       3.0              1.0  média baixa
# 110552                       4.0              2.0        média
# 110553                       5.0              1.0        média
# 110554                       4.0              1.0        média
# 110555                       3.0              1.0  média baixa
# 110556                       7.0              1.0         alta
# 110557                       4.0              2.0  média baixa
# 110558                       5.0              3.0        média
# 110560                       5.0              1.0        média
# 110561                       5.0              2.0        média
# 110562                       5.0              2.0        média
# 110563                       7.0              1.0         alta
# 110564                       4.0              2.0  média baixa
# 110565                       3.0              2.0  média baixa
# 110566                       4.0              2.0        média
# 110568                       5.0              2.0        média
# 110569                       4.0              2.0  média baixa
# 110571                       3.0              2.0  média baixa
# 110574                       4.0              2.0  média baixa
# ...                          ...              ...          ...
# 118179                       2.0              3.0        baixa
# 118180                       3.0              1.0  média baixa
# 118181                       4.0              1.0  média baixa
# 118182                       4.0              2.0  média baixa
# 118183                       4.0              3.0        média
# 118184                       4.0              1.0  média baixa
# 118185                       4.0              3.0  média baixa
# 118186                       3.0              2.0  média baixa
# 118187                       4.0              1.0        média
# 118188                       4.0              1.0  média baixa
# 118191                       1.0              1.0        baixa
# 118192                       3.0              2.0  média baixa
# 118193                       2.0              1.0        baixa
# 118196                       2.0              1.0        baixa
# 118197                       4.0              4.0  média baixa
# 118198                       4.0              1.0        média
# 118199                       6.0              3.0         alta
# 118200                       3.0              3.0  média baixa
# 118201                       7.0              2.0         alta
# 118202                       4.0              3.0  média baixa
# 118203                       3.0              1.0  média baixa
# 118204                       4.0              1.0        média
# 118205                       4.0              1.0        média
# 118206                       2.0              1.0        baixa
# 118207                       4.0              1.0  média baixa
# 118208                       3.0              1.0  média baixa
# 118209                       3.0              1.0        baixa
# 118210                       4.0              2.0  média baixa
# 118211                       4.0              1.0  média baixa
# 118212                       5.0              3.0        média
#
# [6290 rows x 7 columns]

# %% [markdown]
# ___
# ### 2013

# %%
#Indices de 2013 com limpeza de Dados 
data = pd.read_csv('DOM2013.csv',sep=',')
data_resume_2013 = data.loc[:,['UF','V02270','V02271','V02322','V4614','V4621','V4622']]
data_resume_2013 = pd.DataFrame(data_resume_2013[data_resume_2013["UF"].isin(["41"])])
data_resume_2013['Num.Televisores'] = data_resume_2013['V02270'] + data_resume_2013['V02271']
del data_resume_2013['V02270']
del data_resume_2013['V02271']
data_resume_2013 = data_resume_2013.rename(columns = {'V02322' : 'Internet','V4614':'Rend.mens.Domiciliar','V4621':'Ren.mens.percapta','V4622':'Faixa.Rend.mens.percapta'})
data_resume_2013['Internet'] = data_resume_2013['Internet'].astype('category')
data_resume_2013['UF'] = data_resume_2013['UF'].astype('category')
data_resume_2013['Rend.mens.Domiciliar'] =data_resume_2013['Rend.mens.Domiciliar'].astype('float')
data_resume_2013['Ren.mens.percapta'] = data_resume_2013['Ren.mens.percapta'].astype('float')
data_resume_2013.Internet.cat.categories = (['Sim', 'Nao'])
data_resume_2013.UF.cat.categories = (['PR'])
data_resume_2013 = data_resume_2013[data_resume_2013['Rend.mens.Domiciliar']!=999999999999.0]
data_resume_2015 = data_resume_2013[data_resume_2013['Faixa.Rend.mens.percapta']!=999999999999.0]
data_resume_2013 = data_resume_2013[pd.notnull(data_resume_2013['Internet'])&pd.notnull(data_resume_2013['Rend.mens.Domiciliar'])&pd.notnull(data_resume_2013['Ren.mens.percapta'])&pd.notnull(data_resume_2013['Num.Televisores'])]
#pd.DataFrame(data_resume_2013)
#----------------------------------------------------------------
baixa = 441
media = 1019
alta = 2480
data_resume_2013.loc[data_resume_2013['Ren.mens.percapta'] < baixa, "Classe"] = "baixa"
data_resume_2013.loc[(data_resume_2013['Ren.mens.percapta'] > baixa)&(data_resume_2013['Ren.mens.percapta']<media), "Classe"] = "média baixa"
data_resume_2013.loc[(data_resume_2013['Ren.mens.percapta'] > media)&(data_resume_2013['Ren.mens.percapta']<alta),'Classe'] = 'média'
data_resume_2013.loc[data_resume_2013['Ren.mens.percapta'] > alta, "Classe"] = "alta"
#----------------------------------------------------------------
pd.DataFrame(data_resume_2013)
# Out:
#         UF Internet  Rend.mens.Domiciliar  Ren.mens.percapta  \
# 108606  PR      Sim                3300.0             1650.0
# 108607  PR      Nao                2800.0              400.0
# 108608  PR      Nao                2500.0              833.0
# 108609  PR      Nao                2780.0              347.0
# 108610  PR      Nao                 678.0              678.0
# 108612  PR      Sim                2357.0              589.0
# 108613  PR      Sim                2356.0              471.0
# 108614  PR      Sim                3900.0             1950.0
# 108615  PR      Nao                4205.0              525.0
# 108616  PR      Sim                   0.0                0.0
# 108617  PR      Nao                   0.0                0.0
# 108618  PR      Nao                5076.0              725.0
# 108620  PR      Nao                3250.0              812.0
# 108621  PR      Sim                4000.0             2000.0
# 108622  PR      Nao                 678.0              339.0
# 108624  PR      Sim                2760.0              920.0
# 108625  PR      Sim                 935.0              311.0
# 108627  PR      Sim                2070.0              295.0
# 108629  PR      Nao                6200.0             2066.0
# 108630  PR      Nao                3202.0              800.0
# 108631  PR      Sim                 678.0              678.0
# 108632  PR      Nao                1878.0              626.0
# 108633  PR      Sim                6000.0             1500.0
# 108634  PR      Nao                2150.0              716.0
# 108635  PR      Sim                3678.0              525.0
# 108636  PR      Nao                3500.0              875.0
# 108637  PR      Nao                1500.0              750.0
# 108640  PR      Nao                4000.0             1000.0
# 108641  PR      Sim                1300.0              325.0
# 108642  PR      Sim                1500.0              300.0
# ...     ..      ...                   ...                ...
# 116015  PR      Nao                1028.0              514.0
# 116016  PR      Nao                1650.0              412.0
# 116017  PR      Nao                3300.0             1100.0
# 116019  PR      Nao                2712.0              678.0
# 116021  PR      Nao                 200.0              100.0
# 116022  PR      Nao                4340.0              868.0
# 116023  PR      Sim                2478.0              826.0
# 116024  PR      Nao                2300.0              766.0
# 116025  PR      Nao                 678.0              226.0
# 116026  PR      Sim                2670.0              534.0
# 116027  PR      Sim                1900.0              633.0
# 116028  PR      Nao                1630.0              407.0
# 116029  PR      Sim                 980.0              326.0
# 116030  PR      Sim                1890.0              472.0
# 116032  PR      Sim                 950.0              950.0
# 116033  PR      Sim                2300.0             1150.0
# 116034  PR      Nao                1215.0             1215.0
# 116036  PR      Sim                3399.0              849.0
# 116037  PR      Nao                3000.0             1500.0
# 116038  PR      Nao                 678.0              678.0
# 116039  PR      Sim                3378.0              844.0
# 116040  PR      Nao                1000.0              500.0
# 116041  PR      Sim                3200.0              640.0
# 116042  PR      Nao                 800.0              266.0
# 116043  PR      Nao                 678.0              678.0
# 116044  PR      Nao                   0.0                0.0
# 116045  PR      Nao                1900.0              475.0
# 116046  PR      Sim                3078.0             1539.0
# 116047  PR      Sim                7500.0             3750.0
# 116048  PR      Sim                1878.0              939.0
#
#         Faixa.Rend.mens.percapta  Num.Televisores       Classe
# 108606                       5.0              1.0        média
# 108607                       3.0              3.0        baixa
# 108608                       4.0              2.0  média baixa
# 108609                       3.0              2.0        baixa
# 108610                       3.0              1.0  média baixa
# 108612                       3.0              2.0  média baixa
# 108613                       3.0              2.0  média baixa
# 108614                       5.0              2.0        média
# 108615                       3.0              1.0  média baixa
# 108616                       0.0              1.0        baixa
# 108617                       0.0              1.0        baixa
# 108618                       4.0              1.0  média baixa
# 108620                       4.0              2.0  média baixa
# 108621                       5.0              1.0        média
# 108622                       2.0              1.0        baixa
# 108624                       4.0              2.0  média baixa
# 108625                       2.0              1.0        baixa
# 108627                       2.0              3.0        baixa
# 108629                       6.0              4.0        média
# 108630                       4.0              2.0  média baixa
# 108631                       3.0              1.0  média baixa
# 108632                       3.0              3.0  média baixa
# 108633                       5.0              2.0        média
# 108634                       4.0              1.0  média baixa
# 108635                       3.0              3.0  média baixa
# 108636                       4.0              3.0  média baixa
# 108637                       4.0              1.0  média baixa
# 108640                       4.0              2.0  média baixa
# 108641                       2.0              2.0        baixa
# 108642                       2.0              2.0        baixa
# ...                          ...              ...          ...
# 116015                       3.0              1.0  média baixa
# 116016                       3.0              1.0        baixa
# 116017                       4.0              2.0        média
# 116019                       3.0              2.0  média baixa
# 116021                       1.0              1.0        baixa
# 116022                       4.0              2.0  média baixa
# 116023                       4.0              2.0  média baixa
# 116024                       4.0              1.0  média baixa
# 116025                       2.0              2.0        baixa
# 116026                       3.0              2.0  média baixa
# 116027                       3.0              3.0  média baixa
# 116028                       3.0              1.0        baixa
# 116029                       2.0              2.0        baixa
# 116030                       3.0              4.0  média baixa
# 116032                       4.0              1.0  média baixa
# 116033                       4.0              1.0        média
# 116034                       4.0              1.0        média
# 116036                       4.0              3.0  média baixa
# 116037                       5.0              1.0        média
# 116038                       3.0              1.0  média baixa
# 116039                       4.0              2.0  média baixa
# 116040                       3.0              2.0  média baixa
# 116041                       3.0              2.0  média baixa
# 116042                       2.0              2.0        baixa
# 116043                       3.0              1.0  média baixa
# 116044                       0.0              2.0        baixa
# 116045                       3.0              1.0  média baixa
# 116046                       5.0              3.0        média
# 116047                       7.0              3.0         alta
# 116048                       4.0              1.0  média baixa
#
# [6040 rows x 7 columns]

# %% [markdown]
# #### Dados variados sobre as colunas qualitativas fazendo uma comparaçao entre o uso de internet com a renda mensal dos anos de 2015, 2014 e 2013, respectivamente...

# %%
#tabela de 2015:
print("2015:--------------------------------------")
print("para os que possuem internet: ")
rendaM_Sim = data_resume_2015["Rend.mens.Domiciliar"][data_resume_2015["Internet"] =='Sim']
print(rendaM_Sim.describe())
print(100*'-')
print("para os que nao possuem internet: ")
rendaM_Nao = data_resume_2015["Rend.mens.Domiciliar"][data_resume_2015["Internet"] =='Nao']
print(rendaM_Nao.describe())
# Out:
# 2015:--------------------------------------
# para os que possuem internet:
# count     3269.000000
# mean      4640.966045
# std       5290.273301
# min          0.000000
# 25%       2034.000000
# 50%       3238.000000
# 75%       5400.000000
# max      90915.000000
# Name: Rend.mens.Domiciliar, dtype: float64
# ----------------------------------------------------------------------------------------------------
# para os que nao possuem internet:
# count     2936.000000
# mean      1956.375681
# std       1961.801714
# min          0.000000
# 25%        980.000000
# 50%       1500.000000
# 75%       2438.500000
# max      63450.000000
# Name: Rend.mens.Domiciliar, dtype: float64

# %%
#tabela de 2014:
print("2014:--------------------------------------")
print("para os que possuem internet: ")
rendaM_Sim_2014 = data_resume_2014["Rend.mens.Domiciliar"][data_resume_2014["Internet"] =='Sim']
print(rendaM_Sim.describe())
#para os que nao possuem internet:
print(100*'-')
print("para os que nao possuem internet: ")
rendaM_Nao_2014 = data_resume_2014["Rend.mens.Domiciliar"][data_resume_2014["Internet"] =='Nao']
print(rendaM_Nao.describe())
# Out:
# 2014:--------------------------------------
# para os que possuem internet:
# count     3269.000000
# mean      4640.966045
# std       5290.273301
# min          0.000000
# 25%       2034.000000
# 50%       3238.000000
# 75%       5400.000000
# max      90915.000000
# Name: Rend.mens.Domiciliar, dtype: float64
# ----------------------------------------------------------------------------------------------------
# para os que nao possuem internet:
# count     2936.000000
# mean      1956.375681
# std       1961.801714
# min          0.000000
# 25%        980.000000
# 50%       1500.000000
# 75%       2438.500000
# max      63450.000000
# Name: Rend.mens.Domiciliar, dtype: float64

# %%
#tabela de 2013:
print("2013:--------------------------------------")
print("para os que possuem internet: ")
rendaM_Sim_2013 = data_resume_2013["Rend.mens.Domiciliar"][data_resume_2013["Internet"] =='Sim']
print(rendaM_Sim.describe())
#para os que nao possuem internet:
print(100*'-')
print("para os que nao possuem internet: ")
rendaM_Nao_2013 = data_resume_2013["Rend.mens.Domiciliar"][data_resume_2013["Internet"] =='Nao']
print(rendaM_Nao.describe())
# Out:
# 2013:--------------------------------------
# para os que possuem internet:
# count     3269.000000
# mean      4640.966045
# std       5290.273301
# min          0.000000
# 25%       2034.000000
# 50%       3238.000000
# 75%       5400.000000
# max      90915.000000
# Name: Rend.mens.Domiciliar, dtype: float64
# ----------------------------------------------------------------------------------------------------
# para os que nao possuem internet:
# count     2936.000000
# mean      1956.375681
# std       1961.801714
# min          0.000000
# 25%        980.000000
# 50%       1500.000000
# 75%       2438.500000
# max      63450.000000
# Name: Rend.mens.Domiciliar, dtype: float64

# %% [markdown]
# ### Criação de Graficos de Variaveis Quantitativas:

# %%
#DADOS de 2015 para o calculo da frequencias e criação de graficos:
#utilizadores
#print("Frequencia relativa do Grafico de 2015 para utlizadores de internet:")
ray = np.arange(0,60000,1000)
varCat = pd.cut(rendaM_Sim,ray)
#print(varCat.value_counts())
#Nao utilizadores
#print("Frequencia relativa do Grafico de 2015 para nao utlizadores de internet:")
ray_nao = np.arange(0,21000,1000)
varCat_nao = pd.cut(rendaM_Nao,ray)
#print(varCat_nao.value_counts())

# %%
plot_Sim = plt.hist(rendaM_Sim, bins=ray,normed = False,color=('blue'),label ="Utiliza internet",histtype='step',align='right')
blue_patch = mpatches.Patch(color='blue', label='Utiliza Internet')
#plt.legend(handles=[blue_patch])
plt.ylabel('frequencia relativa')
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
plt.title('2015-Relação Renda com internet')
plot_Nao = plt.hist(rendaM_Nao, bins=ray,normed = False,color=('red'),label ="NAO utiliza internet",histtype='step',align='right')
red_patch = mpatches.Patch(color='red', label='Nao Utiliza Internet')
plt.ylabel('frequencia relativa')
plt.legend(handles=[red_patch,blue_patch])
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
# Out:
# (0, 1200)

# %%
#DADOS de 2014 para o calculo da frequencias e criação de graficos:
#utilizadores
#print("Frequencia relativa do Grafico de 2014 para utlizadores de internet:")
ray = np.arange(0,51700,1000)
varCat = pd.cut(rendaM_Sim_2014,ray)
#print(varCat.value_counts())
#Nao utilizadores
#print("Frequencia relativa do Grafico de 2014 para nao utlizadores de internet:")
ray_nao = np.arange(0,48000,1000)
varCat_nao = pd.cut(rendaM_Nao_2014,ray)
#print(varCat_nao.value_counts())

# %%
plot_Sim = plt.hist(rendaM_Sim_2014, bins=ray,normed = False,color=('blue'),label ="Utiliza internet",histtype='step',align='right')
blue_patch = mpatches.Patch(color='blue', label='Utiliza Internet')
#plt.legend(handles=[blue_patch])
plt.ylabel('frequencia relativa')
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
plt.title('2014-Relação Renda com internet')
plot_Nao = plt.hist(rendaM_Nao_2014, bins=ray,normed = False,color=('red'),label ="NAO utiliza internet",histtype='step',align='right')
red_patch = mpatches.Patch(color='red', label='Nao Utiliza Internet')
plt.ylabel('frequencia relativa')
plt.legend(handles=[red_patch,blue_patch])
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
# Out:
# (0, 1200)

# %%
#DADOS de 2014 para o calculo da frequencias e criação de graficos:
#utilizadores
#print("Frequencia relativa do Grafico de 2013 para utlizadores de internet:")
ray = np.arange(0,60000,1000)
varCat = pd.cut(rendaM_Sim_2013,ray)
#print(varCat.value_counts())
#Nao utilizadores
#print("Frequencia relativa do Grafico de 2013 para nao utlizadores de internet:")
ray_nao = np.arange(0,21000,1000)
varCat_nao = pd.cut(rendaM_Nao_2013,ray)
#print(varCat_nao.value_counts())

# %%
plot_Sim = plt.hist(rendaM_Sim_2013, bins=ray,normed = False,color=('blue'),label ="Utiliza internet",histtype='step',align='right')
blue_patch = mpatches.Patch(color='blue', label='Utiliza Internet')
#plt.legend(handles=[blue_patch])
#plt.figure(figsize=(15,5))
plt.ylabel('frequencia relativa')
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
#plt.figure(figsize=(15,5))
plt.title('2013-Relação Renda com internet')
plot_Nao = plt.hist(rendaM_Nao_2013, bins=ray,normed = False,color=('red'),label ="NAO utiliza internet",histtype='step',align='right')
red_patch = mpatches.Patch(color='red', label='Nao Utiliza Internet')
plt.ylabel('frequencia relativa')
plt.legend(handles=[red_patch,blue_patch])
plt.xlabel('Renda mensal')
plt.xlim(0,15000)
plt.ylim(0,1200)
#plt.figure(figsize=(15,5))
plt.show()

# %% [markdown]
# #### Pela analise dos graficos podemos notar que em todos os anos da analise, o uso de internet teve um forte impacto na renda da populaçao do Parana, pois quem nao possuim internet nao atingiu numeros maiores que 15000 reais,ficando limitado a um maximo de renda que é inferior a 15000.Grande parcela da populaçao se encontra na regiao de baixa renda, pois o Brasil é um pais subdesenvolvido e portanto a populaçao de baixa renda possui maior numero de pessoas, assim aumentando a frequencia relativa dos dados.

# %% [markdown]
# #### Tambem é possivel comparar o aumento dos utilizadores de internet durante os ultimos tres anos pela simples razao do desenvolvimento da tecnologia que embarateou, e portanto ficoi mais acessivel a pessoas com uma renda menor, mas ainda assim teve um forte aumento no numero de pessoas que obtiveram sua renda aumetada.

# %% [markdown]
# ### Incersão de gráficos de comparação de Classes sociais em renda per capta:

# %% [markdown]
# # 2015

# %%
#graficos de 2015:
fig,axes = plt.subplots(nrows = 2,ncols=2)

a = data_resume_2015[data_resume_2015.Classe == 'alta']
#pd.DataFrame(a)
v1 = a.Internet.value_counts()

b = data_resume_2015[data_resume_2015.Classe == 'média']
pd.DataFrame(b)
v2 = b.Internet.value_counts()

c = data_resume_2015[data_resume_2015.Classe == 'média baixa']
pd.DataFrame(a)
v3 = c.Internet.value_counts()

d = data_resume_2015[data_resume_2015.Classe == 'baixa']
pd.DataFrame(a)
v4 = d.Internet.value_counts()
v1.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],figsize=(20,20),ax=axes[0,0]); axes[0,0].set_title('Classe: Alta')
v2.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média',figsize=(20,20),ax=axes[1,0]);axes[1,0].set_title('Classe: média')
v3.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média baixa',figsize=(20,20),ax=axes[0,1]);axes[0,1].set_title('Classe: média baixa')
v4.plot(kind='pie',autopct='%1.1f%%',colors=['r','b'],title='Classe: baixa',figsize=(20,20),ax=axes[1,1]);axes[1,1].set_title('Classe: baixa')

# %% [markdown]
# ___
# # 2014

# %%
#graficos de 2014:
fig,axes = plt.subplots(nrows = 2,ncols=2)

a = data_resume_2014[data_resume_2014.Classe == 'alta']
#pd.DataFrame(a)
v1 = a.Internet.value_counts()

b = data_resume_2014[data_resume_2014.Classe == 'média']
pd.DataFrame(b)
v2 = b.Internet.value_counts()

c = data_resume_2014[data_resume_2014.Classe == 'média baixa']
pd.DataFrame(a)
v3 = c.Internet.value_counts()

d = data_resume_2014[data_resume_2014.Classe == 'baixa']
pd.DataFrame(a)
v4 = d.Internet.value_counts()
v1.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],figsize=(20,20),ax=axes[0,0]); axes[0,0].set_title('Classe: Alta')
v2.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média',figsize=(20,20),ax=axes[1,0]);axes[1,0].set_title('Classe: média')
v3.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média baixa',figsize=(20,20),ax=axes[0,1]);axes[0,1].set_title('Classe: média baixa')
v4.plot(kind='pie',autopct='%1.1f%%',colors=['r','b'],title='Classe: baixa',figsize=(20,20),ax=axes[1,1]);axes[1,1].set_title('Classe: baixa')

# %% [markdown]
# ___
# # 2013

# %%
#graficos de 2013:
fig,axes = plt.subplots(nrows = 2,ncols=2)

a = data_resume_2013[data_resume_2013.Classe == 'alta']
#pd.DataFrame(a)
v1 = a.Internet.value_counts()

b = data_resume_2013[data_resume_2013.Classe == 'média']
pd.DataFrame(b)
v2 = b.Internet.value_counts()

c = data_resume_2013[data_resume_2013.Classe == 'média baixa']
pd.DataFrame(a)
v3 = c.Internet.value_counts()

d = data_resume_2013[data_resume_2013.Classe == 'baixa']
pd.DataFrame(a)
v4 = d.Internet.value_counts()
v1.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],figsize=(20,20),ax=axes[0,0]); axes[0,0].set_title('Classe: Alta')
v2.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média',figsize=(20,20),ax=axes[1,0]);axes[1,0].set_title('Classe: média')
v3.plot(kind='pie',autopct='%1.1f%%',colors=['b','r'],title='Classe: média baixa',figsize=(20,20),ax=axes[0,1]);axes[0,1].set_title('Classe: média baixa')
v4.plot(kind='pie',autopct='%1.1f%%',colors=['r','b'],title='Classe: baixa',figsize=(20,20),ax=axes[1,1]);axes[1,1].set_title('Classe: baixa')

# %% [markdown]
# #### crriação do novo "data sheet" para armazenamento dos graficos filtrados

# %%
data_resume_2015.to_csv('Novo_Data_resume_2015.csv')
data_resume_2014.to_csv('Novo_Data_resume_2014.csv')
data_resume_2013.to_csv('Novo_Data_resume_2013.csv')

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!

# %% [markdown]
# A conclusão que é possivel se obter atraves das analises dos dados e dos graficos é que de fato a internet tem sim um certo impacto na renda da população do Parána, permitindo que pessoas de baixa renda consigam subir na hierarquia social ao obter uma provedora de acessoa a internet e possuir assim acesso a esta ampla a infinita fonte de cultura e informação sem contar as vantagens de possuir este beneficio para uma pessoa em seu desenvolvimento social,cultural e proficional. A internet ,ao longo do periodo de estudo, evoluiu e ficou mais barata o que permitiu que mais pessoas nos anos de 2015 e 2014 a possuisem em suas casas como demonstram os histogramas, tambem eh possivel concluir atravaes das analises dos graficos de "pizza" que uma grande parcela da populaçao de renda alta nos três anos estudados possuem internet, assim como os de renda média baixa e média, ambas clases possuem mais que 50% como utilizadores de internet,em quanto pessoas de categorias baixas possuem mais que 60% das pessoas como nao utilizadores de internet.
