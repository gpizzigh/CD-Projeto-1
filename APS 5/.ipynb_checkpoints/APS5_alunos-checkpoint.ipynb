# %% [markdown]
# # APS 5 - Questões com auxílio do Pandas

# %% [markdown]
# ** Nome: ** <font color=black> Gabriel Pizzighini Salvador </font>

# %% [markdown]
# APS **INDIVIDUAL**
#
# Data de Entrega: 26/Set até às 23h59 via GitHub.
#
# Vamos trabalhar com dados do USGS (United States Geological Survey) para tentar determinar se os abalos detectados no hemisfério Norte têm grande probabilidade de serem testes nucleares.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon
import scipy.stats as stats

# %%
#Abrir o arquivo
df = pd.read_csv('earthquake.csv')
#listar colunas
print(list(df))
# Out:
# ['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude', 'Magnitude Type', 'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID', 'Source', 'Location Source', 'Magnitude Source', 'Status']

# %% [markdown]
# ## Liste as primeiras linhas do DataFrame

# %%
df.values.tolist()
# Out:
# [['01/02/1965',
#   '13:44:18',
#   19.246,
#   145.616,
#   'Earthquake',
#   131.6,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860706',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/04/1965',
#   '11:29:49',
#   1.8630000000000002,
#   127.352,
#   'Earthquake',
#   80.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860737',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/05/1965',
#   '18:05:58',
#   -20.579,
#   -173.972,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860762',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/08/1965',
#   '18:49:43',
#   -59.076,
#   -23.557,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860856',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/09/1965',
#   '13:32:50',
#   11.937999999999999,
#   126.427,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860890',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/10/1965',
#   '13:36:32',
#   -13.405,
#   166.62900000000002,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   6.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860922',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/12/1965',
#   '13:32:25',
#   27.357,
#   87.867,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861007',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/15/1965',
#   '23:17:42',
#   -13.309000000000001,
#   166.21200000000002,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861111',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/16/1965',
#   '11:32:37',
#   -56.452,
#   -27.043000000000003,
#   'Earthquake',
#   95.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP861125',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/17/1965',
#   '10:43:17',
#   -24.563000000000002,
#   178.487,
#   'Earthquake',
#   565.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861148',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/17/1965',
#   '20:57:41',
#   -6.807,
#   108.988,
#   'Earthquake',
#   227.9,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861155',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/24/1965',
#   '00:11:17',
#   -2.608,
#   125.95200000000001,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   8.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861299',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['01/29/1965',
#   '09:35:30',
#   54.636,
#   161.703,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM861461',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/01/1965',
#   '05:27:06',
#   -18.697,
#   -177.864,
#   'Earthquake',
#   482.9,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859136',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/02/1965',
#   '15:56:51',
#   37.523,
#   73.251,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859164',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '03:25:00',
#   -51.84,
#   139.741,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859200',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '05:01:22',
#   51.251000000000005,
#   178.715,
#   'Earthquake',
#   30.3,
#   nan,
#   nan,
#   8.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'OFFICIAL19650204050122_30',
#   'OFFICIAL',
#   'ISCGEM',
#   'OFFICIAL',
#   'Automatic'],
#  ['02/04/1965',
#   '06:04:59',
#   51.638999999999996,
#   175.055,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP859215',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '06:37:06',
#   52.528,
#   172.007,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859221',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '06:39:32',
#   51.626000000000005,
#   175.74599999999998,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859222',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '07:11:23',
#   51.037,
#   177.84799999999998,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP859230',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '07:14:59',
#   51.73,
#   173.975,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859231',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '07:23:12',
#   51.775,
#   173.058,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859233',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '07:43:43',
#   52.611000000000004,
#   172.588,
#   'Earthquake',
#   24.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP859241',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '08:06:17',
#   51.831,
#   174.368,
#   'Earthquake',
#   31.8,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859252',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '08:33:41',
#   51.948,
#   173.96900000000002,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859261',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '08:40:44',
#   51.443000000000005,
#   179.605,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   7.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859264',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '12:06:08',
#   52.773,
#   171.97400000000002,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859324',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '12:50:59',
#   51.772,
#   174.696,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859333',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '14:18:29',
#   52.975,
#   171.09099999999998,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859358',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '15:51:25',
#   52.99,
#   170.87400000000002,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859376',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '18:34:12',
#   51.536,
#   175.045,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859400',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '19:44:04',
#   13.245,
#   -44.922,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859419',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/04/1965',
#   '22:30:03',
#   51.812,
#   174.206,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859449',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/05/1965',
#   '06:39:50',
#   51.762,
#   174.84099999999998,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859516',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/05/1965',
#   '09:32:11',
#   52.438,
#   174.321,
#   'Earthquake',
#   39.5,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859539',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/05/1965',
#   '13:38:47',
#   51.946000000000005,
#   173.84,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859570',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/05/1965',
#   '20:47:12',
#   51.738,
#   174.56599999999997,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859611',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/05/1965',
#   '22:16:02',
#   51.486999999999995,
#   176.558,
#   'Earthquake',
#   30.4,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859620',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '01:40:32',
#   53.008,
#   -162.00799999999998,
#   'Earthquake',
#   17.8,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859637',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '04:02:54',
#   52.184,
#   175.505,
#   'Earthquake',
#   27.7,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859650',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '07:14:45',
#   52.076,
#   172.918,
#   'Earthquake',
#   30.1,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859669',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '12:22:28',
#   51.744,
#   175.213,
#   'Earthquake',
#   37.4,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859693',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '14:11:11',
#   52.056999999999995,
#   174.11599999999999,
#   'Earthquake',
#   17.5,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859699',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '16:50:29',
#   53.191,
#   -161.859,
#   'Earthquake',
#   22.5,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859712',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/06/1965',
#   '18:10:30',
#   51.446999999999996,
#   176.46900000000002,
#   'Earthquake',
#   25.2,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859718',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/07/1965',
#   '02:17:08',
#   51.258,
#   173.393,
#   'Earthquake',
#   17.7,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859754',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/07/1965',
#   '04:11:22',
#   52.031000000000006,
#   175.41099999999997,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859764',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/07/1965',
#   '09:25:52',
#   51.294,
#   179.092,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859786',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/08/1965',
#   '15:46:52',
#   55.223,
#   165.426,
#   'Earthquake',
#   32.5,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859882',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/09/1965',
#   '05:42:05',
#   -18.718,
#   169.386,
#   'Earthquake',
#   200.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859915',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/09/1965',
#   '17:37:17',
#   52.815,
#   171.90400000000002,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859942',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/12/1965',
#   '00:55:10',
#   52.188,
#   172.752,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860051',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/15/1965',
#   '01:25:07',
#   51.00899999999999,
#   179.325,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860189',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/15/1965',
#   '10:43:29',
#   3.0260000000000002,
#   125.95100000000001,
#   'Earthquake',
#   100.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP860207',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/16/1965',
#   '12:24:10',
#   38.908,
#   142.095,
#   'Earthquake',
#   53.5,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860246',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/17/1965',
#   '10:18:51',
#   51.693999999999996,
#   176.446,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860280',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/17/1965',
#   '18:23:57',
#   21.526999999999997,
#   143.08100000000002,
#   'Earthquake',
#   340.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860296',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/18/1965',
#   '04:26:37',
#   25.011,
#   94.186,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860307',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/18/1965',
#   '22:39:48',
#   -7.251,
#   126.715,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860339',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/18/1965',
#   '23:13:40',
#   51.415,
#   179.358,
#   'Earthquake',
#   40.4,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860340',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/21/1965',
#   '11:14:18',
#   -15.343,
#   -172.889,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860442',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/23/1965',
#   '22:11:47',
#   -25.633000000000003,
#   -70.679,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   7.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860516',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/25/1965',
#   '04:51:29',
#   -5.461,
#   151.98,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860551',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/25/1965',
#   '05:22:14',
#   51.88399999999999,
#   173.072,
#   'Earthquake',
#   20.3,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860552',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/26/1965',
#   '23:36:14',
#   6.746,
#   -72.971,
#   'Earthquake',
#   160.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860605',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['02/27/1965',
#   '07:46:25',
#   28.133000000000003,
#   -112.208,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM860614',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '07:20:56',
#   -5.377000000000001,
#   152.115,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858179',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '08:18:57',
#   21.104,
#   121.21799999999999,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858182',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '09:08:48',
#   -5.371,
#   152.055,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858184',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '13:20:57',
#   21.122,
#   121.148,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858191',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '19:22:04',
#   52.20399999999999,
#   173.91099999999997,
#   'Earthquake',
#   33.6,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858198',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/01/1965',
#   '21:32:14',
#   15.404000000000002,
#   -92.62299999999999,
#   'Earthquake',
#   105.2,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858202',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/02/1965',
#   '22:00:05',
#   38.399,
#   28.226,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858256',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/03/1965',
#   '14:39:02',
#   -27.145,
#   -177.262,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858295',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/03/1965',
#   '15:14:08',
#   -5.513999999999999,
#   151.819,
#   'Earthquake',
#   14.8,
#   nan,
#   nan,
#   6.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858296',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/03/1965',
#   '16:47:28',
#   53.04600000000001,
#   171.308,
#   'Earthquake',
#   25.7,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858298',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/04/1965',
#   '01:48:56',
#   -5.487,
#   146.993,
#   'Earthquake',
#   200.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858312',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/05/1965',
#   '06:15:04',
#   50.928000000000004,
#   179.511,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858343',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/05/1965',
#   '13:42:47',
#   52.39,
#   174.937,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858354',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/05/1965',
#   '14:32:18',
#   -27.026999999999997,
#   -63.214,
#   'Earthquake',
#   560.8,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858356',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/05/1965',
#   '17:59:16',
#   52.416000000000004,
#   174.239,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858362',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/06/1965',
#   '11:10:51',
#   -18.425,
#   -132.923,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858385',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/06/1965',
#   '20:23:57',
#   20.13,
#   121.461,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858396',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/07/1965',
#   '01:43:11',
#   -29.998,
#   -177.968,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858401',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/09/1965',
#   '17:57:55',
#   39.196999999999996,
#   23.86,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858461',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/13/1965',
#   '07:33:24',
#   53.292,
#   -162.33100000000002,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858558',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/14/1965',
#   '15:53:07',
#   36.405,
#   70.72399999999999,
#   'Earthquake',
#   207.8,
#   nan,
#   nan,
#   7.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858598',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/15/1965',
#   '02:02:09',
#   22.635,
#   121.117,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858608',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/16/1965',
#   '16:46:17',
#   40.696999999999996,
#   143.032,
#   'Earthquake',
#   32.1,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858655',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/17/1965',
#   '14:27:15',
#   52.785,
#   171.821,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858677',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/18/1965',
#   '06:22:12',
#   -20.035999999999998,
#   -175.89,
#   'Earthquake',
#   224.9,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858689',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/18/1965',
#   '12:40:45',
#   -55.857,
#   -26.758000000000003,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858693',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/19/1965',
#   '16:20:53',
#   -1.8869999999999998,
#   119.836,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858722',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/21/1965',
#   '11:08:19',
#   -1.547,
#   126.62299999999999,
#   'Earthquake',
#   28.9,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858755',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/22/1965',
#   '02:44:49',
#   -15.262,
#   -173.25400000000002,
#   'Earthquake',
#   30.5,
#   nan,
#   nan,
#   6.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858772',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/22/1965',
#   '22:56:27',
#   -31.974,
#   -71.57300000000001,
#   'Earthquake',
#   48.8,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858793',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/23/1965',
#   '23:54:05',
#   -15.382,
#   -173.19400000000002,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858819',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/24/1965',
#   '22:42:12',
#   8.418,
#   126.553,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858845',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/28/1965',
#   '13:23:01',
#   55.26,
#   161.904,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858938',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/28/1965',
#   '16:33:16',
#   -32.522,
#   -71.233,
#   'Earthquake',
#   70.0,
#   nan,
#   nan,
#   7.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858940',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/29/1965',
#   '10:47:38',
#   40.687,
#   142.915,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858966',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/30/1965',
#   '00:21:00',
#   -20.502,
#   -173.701,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858978',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/30/1965',
#   '02:27:06',
#   50.282,
#   177.959,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   7.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858982',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['03/31/1965',
#   '09:47:31',
#   38.365,
#   22.405,
#   'Earthquake',
#   75.0,
#   nan,
#   nan,
#   6.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM859094',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/01/1965',
#   '07:08:37',
#   9.986,
#   125.896,
#   'Earthquake',
#   60.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP857323',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/03/1965',
#   '11:20:43',
#   15.8,
#   -98.06700000000001,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857413',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/04/1965',
#   '13:30:39',
#   51.865,
#   175.172,
#   'Earthquake',
#   30.7,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857447',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/04/1965',
#   '15:36:13',
#   -27.088,
#   -176.046,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857450',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/05/1965',
#   '03:12:53',
#   37.505,
#   22.066999999999997,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857472',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/05/1965',
#   '13:52:12',
#   44.812,
#   150.871,
#   'Earthquake',
#   39.2,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857484',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/06/1965',
#   '05:31:59',
#   36.083,
#   139.968,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857506',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/06/1965',
#   '09:42:29',
#   -0.46299999999999997,
#   120.039,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857510',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/08/1965',
#   '13:43:54',
#   52.192,
#   173.437,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857580',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/09/1965',
#   '10:45:26',
#   -32.707,
#   -178.207,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857602',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/09/1965',
#   '23:57:06',
#   35.047,
#   24.318,
#   'Earthquake',
#   65.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857618',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/10/1965',
#   '14:46:51',
#   -20.455,
#   -173.62099999999998,
#   'Earthquake',
#   17.5,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857639',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/10/1965',
#   '22:32:48',
#   -17.857,
#   -178.646,
#   'Earthquake',
#   543.7,
#   nan,
#   nan,
#   6.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857647',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/10/1965',
#   '22:53:05',
#   -13.409,
#   170.37599999999998,
#   'Earthquake',
#   635.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857648',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/11/1965',
#   '00:11:11',
#   -42.692,
#   174.205,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857649',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/11/1965',
#   '18:51:37',
#   -26.168000000000003,
#   178.628,
#   'Earthquake',
#   570.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857677',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/12/1965',
#   '20:41:17',
#   30.316999999999997,
#   138.702,
#   'Earthquake',
#   421.7,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857712',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/15/1965',
#   '05:09:50',
#   25.08,
#   122.897,
#   'Earthquake',
#   165.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857769',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/16/1965',
#   '23:22:21',
#   64.572,
#   -160.375,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857809',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/18/1965',
#   '06:33:58',
#   41.46,
#   -127.416,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857833',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/18/1965',
#   '09:39:19',
#   -59.687,
#   -26.454,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857835',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/18/1965',
#   '12:41:56',
#   -59.586000000000006,
#   -26.372,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857837',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/19/1965',
#   '23:42:00',
#   34.848,
#   138.332,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857881',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/24/1965',
#   '21:55:29',
#   11.450999999999999,
#   140.231,
#   'Earthquake',
#   70.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857999',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/25/1965',
#   '01:00:15',
#   24.409000000000002,
#   142.776,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858003',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/26/1965',
#   '09:47:29',
#   -1.733,
#   126.568,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858039',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/26/1965',
#   '20:29:07',
#   54.157,
#   -162.59,
#   'Earthquake',
#   36.8,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858049',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/26/1965',
#   '22:15:45',
#   21.045,
#   120.79799999999999,
#   'Earthquake',
#   37.1,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858053',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/27/1965',
#   '10:54:24',
#   -6.822,
#   129.504,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858070',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/27/1965',
#   '14:09:10',
#   35.626,
#   23.425,
#   'Earthquake',
#   60.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858076',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/27/1965',
#   '20:09:17',
#   1.3330000000000002,
#   -85.075,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858082',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/29/1965',
#   '15:28:45',
#   47.288000000000004,
#   -122.406,
#   'Earthquake',
#   64.7,
#   nan,
#   nan,
#   6.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM858143',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['04/29/1965',
#   '15:48:55',
#   -5.547999999999999,
#   110.33200000000001,
#   'Earthquake',
#   480.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP858144',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/01/1965',
#   '21:27:54',
#   60.35,
#   -146.17600000000002,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856572',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/02/1965',
#   '07:13:45',
#   28.927,
#   128.769,
#   'Earthquake',
#   22.5,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856581',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/03/1965',
#   '01:09:34',
#   -32.537,
#   -70.569,
#   'Earthquake',
#   90.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856594',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/03/1965',
#   '10:01:38',
#   13.683,
#   -89.07,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856602',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/03/1965',
#   '16:09:09',
#   -24.281,
#   -67.92699999999999,
#   'Earthquake',
#   110.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856609',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/04/1965',
#   '08:34:43',
#   41.801,
#   79.414,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856624',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/12/1965',
#   '08:05:56',
#   -3.523,
#   137.924,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856806',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/12/1965',
#   '10:33:47',
#   -6.1739999999999995,
#   130.358,
#   'Earthquake',
#   153.1,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856810',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/15/1965',
#   '23:58:36',
#   -4.131,
#   134.946,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856887',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/16/1965',
#   '11:35:47',
#   5.268,
#   125.46700000000001,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856902',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/17/1965',
#   '17:19:33',
#   22.336,
#   121.24799999999999,
#   'Earthquake',
#   68.4,
#   nan,
#   nan,
#   6.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856924',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/19/1965',
#   '03:00:58',
#   -8.937999999999999,
#   159.083,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856977',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/19/1965',
#   '06:03:56',
#   -6.575,
#   105.311,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856984',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/19/1965',
#   '13:59:55',
#   -4.819,
#   152.436,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856995',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1965',
#   '00:40:27',
#   -14.921,
#   167.34,
#   'Earthquake',
#   120.0,
#   nan,
#   nan,
#   7.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857011',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/22/1965',
#   '03:05:46',
#   1.3090000000000002,
#   126.23899999999999,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857068',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/22/1965',
#   '10:31:39',
#   -21.125999999999998,
#   -178.537,
#   'Earthquake',
#   553.8,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857075',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/23/1965',
#   '23:46:15',
#   52.148999999999994,
#   175.11900000000003,
#   'Earthquake',
#   28.5,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857113',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/24/1965',
#   '23:21:12',
#   13.174000000000001,
#   124.604,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857130',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/25/1965',
#   '13:07:51',
#   51.227,
#   178.882,
#   'Earthquake',
#   30.1,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857142',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/26/1965',
#   '19:44:13',
#   -55.957,
#   -27.875,
#   'Earthquake',
#   125.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP857167',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/31/1965',
#   '11:38:42',
#   -7.566,
#   128.578,
#   'Earthquake',
#   150.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM857305',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/02/1965',
#   '05:13:00',
#   -23.54,
#   -179.917,
#   'Earthquake',
#   540.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855792',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/02/1965',
#   '23:40:23',
#   15.674000000000001,
#   -46.711999999999996,
#   'Earthquake',
#   12.5,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855811',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/05/1965',
#   '03:49:03',
#   -1.649,
#   126.552,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855868',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '02:37:35',
#   51.88399999999999,
#   174.015,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855987',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '03:33:47',
#   44.608000000000004,
#   149.02200000000002,
#   'Earthquake',
#   40.7,
#   nan,
#   nan,
#   7.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855990',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '03:34:04',
#   44.578,
#   148.69899999999998,
#   'Earthquake',
#   58.0,
#   nan,
#   nan,
#   7.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855991',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '07:11:04',
#   44.133,
#   149.255,
#   'Earthquake',
#   31.6,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856010',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '07:27:44',
#   44.111999999999995,
#   149.539,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856011',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/11/1965',
#   '08:41:01',
#   44.299,
#   149.032,
#   'Earthquake',
#   32.6,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856015',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1965',
#   '05:28:40',
#   44.167,
#   149.87,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856064',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1965',
#   '05:40:58',
#   43.775,
#   149.44799999999998,
#   'Earthquake',
#   38.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856066',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1965',
#   '06:03:33',
#   43.803999999999995,
#   149.351,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856067',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1965',
#   '18:45:44',
#   43.885,
#   149.339,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856087',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1965',
#   '18:50:12',
#   -20.38,
#   -68.944,
#   'Earthquake',
#   102.2,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856088',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/13/1965',
#   '07:06:15',
#   41.705,
#   143.727,
#   'Earthquake',
#   38.1,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856098',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/13/1965',
#   '20:01:51',
#   37.718,
#   29.378,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856108',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/14/1965',
#   '07:30:42',
#   -39.902,
#   45.55,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856118',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/15/1965',
#   '09:20:34',
#   -38.08,
#   177.442,
#   'Earthquake',
#   95.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP856141',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/15/1965',
#   '23:10:29',
#   -21.025,
#   173.574,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856155',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/17/1965',
#   '20:14:51',
#   32.052,
#   87.78399999999999,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856219',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/20/1965',
#   '01:57:26',
#   44.505,
#   149.218,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856278',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/20/1965',
#   '18:04:34',
#   42.973,
#   -126.652,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856293',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/21/1965',
#   '00:21:17',
#   28.134,
#   55.891000000000005,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856301',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/22/1965',
#   '23:48:07',
#   7.175,
#   123.613,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856343',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/23/1965',
#   '11:09:17',
#   56.543,
#   -152.94799999999998,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856357',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/24/1965',
#   '07:45:13',
#   7.034,
#   126.25,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856382',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/27/1965',
#   '09:45:45',
#   -54.437,
#   4.965,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856447',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/27/1965',
#   '11:08:59',
#   60.281000000000006,
#   -141.418,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856449',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/27/1965',
#   '11:36:14',
#   23.764,
#   121.56,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856452',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/28/1965',
#   '03:33:35',
#   -5.01,
#   153.06,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856478',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/30/1965',
#   '02:53:16',
#   -1.734,
#   126.53,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856531',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/30/1965',
#   '08:33:33',
#   51.813,
#   176.53,
#   'Earthquake',
#   44.6,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM856536',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/01/1965',
#   '23:12:42',
#   -63.159,
#   -163.707,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855097',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/02/1965',
#   '20:58:40',
#   52.99,
#   -167.739,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   7.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855112',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/03/1965',
#   '11:26:13',
#   22.338,
#   101.49600000000001,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855121',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/06/1965',
#   '03:04:21',
#   -22.566999999999997,
#   172.93900000000002,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP855168',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/06/1965',
#   '03:18:45',
#   38.384,
#   22.545,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855169',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/06/1965',
#   '04:08:49',
#   46.591,
#   152.467,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855170',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/06/1965',
#   '18:36:46',
#   -4.408,
#   155.062,
#   'Earthquake',
#   490.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855189',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/07/1965',
#   '23:00:00',
#   -6.819,
#   105.505,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855208',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/12/1965',
#   '13:57:15',
#   -28.428,
#   -68.25,
#   'Earthquake',
#   112.4,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855319',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/15/1965',
#   '18:33:30',
#   7.74,
#   123.811,
#   'Earthquake',
#   570.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855394',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/17/1965',
#   '07:20:34',
#   -9.72,
#   159.888,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855425',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/20/1965',
#   '13:18:28',
#   7.56,
#   124.24700000000001,
#   'Earthquake',
#   24.6,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855504',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/21/1965',
#   '17:52:33',
#   53.318000000000005,
#   170.365,
#   'Earthquake',
#   28.8,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855526',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/25/1965',
#   '03:40:43',
#   1.8130000000000002,
#   99.27600000000001,
#   'Earthquake',
#   105.0,
#   nan,
#   nan,
#   5.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855580',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/25/1965',
#   '13:33:04',
#   41.278,
#   146.68200000000002,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855589',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/25/1965',
#   '21:46:45',
#   51.472,
#   175.894,
#   'Earthquake',
#   20.1,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855597',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/28/1965',
#   '22:29:09',
#   -2.335,
#   101.76700000000001,
#   'Earthquake',
#   140.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855664',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/29/1965',
#   '08:29:24',
#   51.05,
#   -171.28900000000002,
#   'Earthquake',
#   21.4,
#   nan,
#   nan,
#   6.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855674',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/29/1965',
#   '12:20:21',
#   50.799,
#   -171.607,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855684',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/29/1965',
#   '15:08:37',
#   51.076,
#   -171.46599999999998,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855692',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/30/1965',
#   '07:20:10',
#   6.789,
#   -72.907,
#   'Earthquake',
#   160.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM855709',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['08/01/1965',
#   '23:44:29',
#   -32.441,
#   -178.803,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM854282',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['08/02/1965',
#   '13:19:57',
#   -56.04600000000001,
#   157.922,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   7.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM854292',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['08/03/1965',
#   '02:01:53',
#   -7.526,
#   -81.179,
#   'Earthquake',
#   26.3,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
# ...
#   nan,
#   nan,
#   nan,
#   'ISCGEM822368',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1968',
#   '03:16:20',
#   40.15,
#   144.063,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822379',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1968',
#   '07:13:09',
#   -30.799,
#   -178.11,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   7.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822391',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1968',
#   '10:34:20',
#   48.736999999999995,
#   154.903,
#   'Earthquake',
#   51.9,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822397',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1968',
#   '20:05:51',
#   -30.725,
#   -178.08700000000002,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   6.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822409',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/20/1968',
#   '21:09:46',
#   44.821999999999996,
#   150.219,
#   'Earthquake',
#   28.3,
#   nan,
#   nan,
#   7.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822412',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/21/1968',
#   '00:19:35',
#   44.758,
#   150.255,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822418',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/21/1968',
#   '04:11:26',
#   41.162,
#   143.667,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822432',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/21/1968',
#   '08:20:02',
#   44.878,
#   150.186,
#   'Earthquake',
#   31.3,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822444',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/21/1968',
#   '11:00:46',
#   44.736999999999995,
#   150.244,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822449',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/22/1968',
#   '10:51:55',
#   41.528999999999996,
#   143.031,
#   'Earthquake',
#   45.1,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822518',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/22/1968',
#   '19:29:28',
#   40.25,
#   142.51,
#   'Earthquake',
#   48.5,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822541',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/23/1968',
#   '17:24:18',
#   -41.659,
#   172.02,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   7.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822588',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/24/1968',
#   '14:06:24',
#   40.881,
#   143.178,
#   'Earthquake',
#   27.6,
#   nan,
#   nan,
#   6.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822745',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/24/1968',
#   '15:43:56',
#   -6.7989999999999995,
#   118.853,
#   'Earthquake',
#   619.1,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822753',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/24/1968',
#   '20:57:26',
#   -41.93899999999999,
#   171.99900000000002,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822768',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/25/1968',
#   '11:52:58',
#   40.179,
#   143.29,
#   'Earthquake',
#   31.8,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM822812',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/28/1968',
#   '09:06:31',
#   -30.785999999999998,
#   -177.63,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM823083',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/28/1968',
#   '13:27:19',
#   -2.85,
#   139.35299999999998,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   7.5,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM823104',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/28/1968',
#   '22:30:00',
#   52.215,
#   172.763,
#   'Earthquake',
#   20.5,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM823128',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/30/1968',
#   '05:23:48',
#   44.65,
#   150.259,
#   'Earthquake',
#   24.2,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM823251',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['05/30/1968',
#   '19:42:26',
#   -30.928,
#   -177.39700000000002,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM823302',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/01/1968',
#   '10:31:50',
#   40.251999999999995,
#   142.39700000000002,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819574',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/02/1968',
#   '08:18:37',
#   -8.076,
#   158.673,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819628',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/03/1968',
#   '14:16:19',
#   45.445,
#   148.584,
#   'Earthquake',
#   155.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819717',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/07/1968',
#   '11:57:34',
#   -1.916,
#   120.094,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   6.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819942',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/07/1968',
#   '21:30:55',
#   -2.0780000000000003,
#   120.462,
#   'Earthquake',
#   38.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819969',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/08/1968',
#   '00:16:39',
#   -8.74,
#   157.558,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819976',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/08/1968',
#   '05:29:48',
#   43.54,
#   147.096,
#   'Earthquake',
#   40.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819990',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/08/1968',
#   '23:24:03',
#   -48.946000000000005,
#   31.122,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820030',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/10/1968',
#   '12:41:07',
#   56.28,
#   -161.493,
#   'Earthquake',
#   186.1,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP820098',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1968',
#   '13:41:53',
#   39.503,
#   143.07,
#   'Earthquake',
#   32.1,
#   nan,
#   nan,
#   7.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820211',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1968',
#   '20:15:49',
#   -0.591,
#   132.909,
#   'Earthquake',
#   35.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820257',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/12/1968',
#   '21:57:42',
#   39.361999999999995,
#   142.955,
#   'Earthquake',
#   27.5,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820262',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/13/1968',
#   '11:56:24',
#   39.235,
#   143.187,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820301',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/13/1968',
#   '21:10:37',
#   39.421,
#   143.097,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820322',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/14/1968',
#   '11:52:39',
#   39.306,
#   142.99200000000002,
#   'Earthquake',
#   24.5,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820355',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/14/1968',
#   '12:17:25',
#   45.25,
#   153.351,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820358',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/15/1968',
#   '05:59:05',
#   26.88,
#   126.514,
#   'Earthquake',
#   140.0,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820398',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/15/1968',
#   '07:08:49',
#   5.591,
#   -82.54899999999999,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.2,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820399',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/15/1968',
#   '11:27:33',
#   51.633,
#   159.325,
#   'Earthquake',
#   30.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820412',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/16/1968',
#   '19:14:05',
#   -53.827,
#   8.766,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820509',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/17/1968',
#   '11:53:01',
#   41.053999999999995,
#   143.259,
#   'Earthquake',
#   37.6,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820557',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/17/1968',
#   '18:09:37',
#   -12.300999999999998,
#   166.567,
#   'Earthquake',
#   50.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820583',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/17/1968',
#   '18:57:30',
#   38.745,
#   143.918,
#   'Earthquake',
#   25.0,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820585',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/19/1968',
#   '08:13:35',
#   -5.61,
#   -77.086,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820734',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/19/1968',
#   '19:58:03',
#   -44.053999999999995,
#   -75.583,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820811',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/20/1968',
#   '02:38:37',
#   -5.5729999999999995,
#   -77.184,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820847',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/21/1968',
#   '00:26:08',
#   -5.705,
#   -77.258,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM820933',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/22/1968',
#   '01:12:33',
#   40.406,
#   143.767,
#   'Earthquake',
#   18.2,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM821004',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/25/1968',
#   '23:33:20',
#   39.585,
#   143.58700000000002,
#   'Earthquake',
#   20.7,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM821218',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/26/1968',
#   '10:23:51',
#   42.037,
#   142.89700000000002,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM821247',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['06/26/1968',
#   '15:40:31',
#   -22.206999999999997,
#   171.315,
#   'Earthquake',
#   80.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM821259',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/01/1968',
#   '10:45:12',
#   35.999,
#   139.34799999999998,
#   'Earthquake',
#   60.6,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818523',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/02/1968',
#   '03:44:52',
#   17.515,
#   -100.273,
#   'Earthquake',
#   57.9,
#   nan,
#   nan,
#   6.4,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818550',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/02/1968',
#   '04:30:53',
#   -29.915,
#   -177.69,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818552',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/02/1968',
#   '18:40:10',
#   -2.7119999999999997,
#   138.891,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818568',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/05/1968',
#   '11:28:14',
#   38.478,
#   142.153,
#   'Earthquake',
#   47.0,
#   nan,
#   nan,
#   6.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818662',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/06/1968',
#   '19:29:00',
#   -6.477,
#   133.887,
#   'Earthquake',
#   55.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEMSUP818727',
#   'ISCGEMSUP',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/10/1968',
#   '11:16:45',
#   -36.772,
#   78.413,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818882',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/10/1968',
#   '20:40:31',
#   40.211,
#   143.472,
#   'Earthquake',
#   20.0,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818892',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/12/1968',
#   '00:44:37',
#   39.554,
#   143.238,
#   'Earthquake',
#   21.8,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818928',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/12/1968',
#   '03:56:28',
#   39.623000000000005,
#   143.27700000000002,
#   'Earthquake',
#   19.9,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM818931',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/17/1968',
#   '05:24:15',
#   -8.619,
#   125.008,
#   'Earthquake',
#   12.4,
#   nan,
#   nan,
#   5.9,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819094',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/19/1968',
#   '04:56:26',
#   8.727,
#   93.626,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819166',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/21/1968',
#   '06:09:42',
#   -3.112,
#   150.6,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819218',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/22/1968',
#   '05:09:14',
#   -54.73,
#   1.5,
#   'Earthquake',
#   10.0,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819246',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/22/1968',
#   '17:58:33',
#   -20.154,
#   169.011,
#   'Earthquake',
#   38.4,
#   nan,
#   nan,
#   5.6,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819263',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/23/1968',
#   '23:02:39',
#   40.387,
#   143.505,
#   'Earthquake',
#   26.7,
#   nan,
#   nan,
#   6.0,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819294',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/25/1968',
#   '07:23:07',
#   -30.725,
#   -178.217,
#   'Earthquake',
#   45.0,
#   nan,
#   nan,
#   7.3,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819340',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/25/1968',
#   '10:50:33',
#   45.558,
#   146.861,
#   'Earthquake',
#   17.3,
#   nan,
#   nan,
#   5.8,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819351',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/27/1968',
#   '10:51:32',
#   -19.188,
#   176.024,
#   'Earthquake',
#   15.0,
#   nan,
#   nan,
#   5.7,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819418',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ['07/28/1968',
#   '21:12:40',
#   55.42,
#   166.565,
#   'Earthquake',
#   23.6,
#   nan,
#   nan,
#   6.1,
#   'MW',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'ISCGEM819452',
#   'ISCGEM',
#   'ISCGEM',
#   'ISCGEM',
#   'Automatic'],
#  ...]

# %% [markdown]
# ## Q1 - Manipulando o DataFrame
#
# Crie uma coluna chamada `Hemisfério` baseada na Latitude
#
# A regra de formação é a seguinte:
#
# Valor | Critério
# ---|---
# Norte | Latitude positiva
# Sul | Latitude negativa

# %%
if "Depth Error" in list(df): 
#deletando colunas inuteis:
    del  df["Depth Error"]
    del  df["Depth Seismic Stations"]
    del  df["Magnitude Seismic Stations"]
    del  df["Azimuthal Gap"]
    del  df["Horizontal Distance"]
    del  df["Horizontal Error"]
    del  df["Root Mean Square"]
#removendo NAN:
#df = df.iloc(df['Magnitude Error'][pd.notnull(df["Magnitude Error"])])
#criando a formatação
df["Hemisferio"] = ''
hemi = []
for n in range(len(df)):
    if df.Latitude.iloc[n] >= 0: #consideredando uma latitutude igual a zero no Hemisfério Norte
        hemi.append("Norte")
    else:
        hemi.append("Sul")
df["Hemisferio"] = pd.Series(hemi)
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# 5      01/10/1965  13:36:32  -13.4050   166.6290  Earthquake   35.00
# 6      01/12/1965  13:32:25   27.3570    87.8670  Earthquake   20.00
# 7      01/15/1965  23:17:42  -13.3090   166.2120  Earthquake   35.00
# 8      01/16/1965  11:32:37  -56.4520   -27.0430  Earthquake   95.00
# 9      01/17/1965  10:43:17  -24.5630   178.4870  Earthquake  565.00
# 10     01/17/1965  20:57:41   -6.8070   108.9880  Earthquake  227.90
# 11     01/24/1965  00:11:17   -2.6080   125.9520  Earthquake   20.00
# 12     01/29/1965  09:35:30   54.6360   161.7030  Earthquake   55.00
# 13     02/01/1965  05:27:06  -18.6970  -177.8640  Earthquake  482.90
# 14     02/02/1965  15:56:51   37.5230    73.2510  Earthquake   15.00
# 15     02/04/1965  03:25:00  -51.8400   139.7410  Earthquake   10.00
# 16     02/04/1965  05:01:22   51.2510   178.7150  Earthquake   30.30
# 17     02/04/1965  06:04:59   51.6390   175.0550  Earthquake   30.00
# 18     02/04/1965  06:37:06   52.5280   172.0070  Earthquake   25.00
# 19     02/04/1965  06:39:32   51.6260   175.7460  Earthquake   25.00
# 20     02/04/1965  07:11:23   51.0370   177.8480  Earthquake   25.00
# 21     02/04/1965  07:14:59   51.7300   173.9750  Earthquake   20.00
# 22     02/04/1965  07:23:12   51.7750   173.0580  Earthquake   10.00
# 23     02/04/1965  07:43:43   52.6110   172.5880  Earthquake   24.00
# 24     02/04/1965  08:06:17   51.8310   174.3680  Earthquake   31.80
# 25     02/04/1965  08:33:41   51.9480   173.9690  Earthquake   20.00
# 26     02/04/1965  08:40:44   51.4430   179.6050  Earthquake   30.00
# 27     02/04/1965  12:06:08   52.7730   171.9740  Earthquake   30.00
# 28     02/04/1965  12:50:59   51.7720   174.6960  Earthquake   20.00
# 29     02/04/1965  14:18:29   52.9750   171.0910  Earthquake   25.00
# ...           ...       ...       ...        ...         ...     ...
# 23382  12/11/2016  17:26:10  -10.9640   161.5723  Earthquake   10.00
# 23383  12/14/2016  02:01:23   21.2897   144.4037  Earthquake   22.37
# 23384  12/14/2016  21:14:56   21.3697   144.2175  Earthquake   10.00
# 23385  12/16/2016  11:34:58   14.0882   -90.8691  Earthquake   71.26
# 23386  12/17/2016  10:51:10   -4.5049   153.5216  Earthquake   94.54
# 23387  12/17/2016  11:22:40   -4.4244   153.5419  Earthquake   83.36
# 23388  12/17/2016  11:27:39   -5.6497   153.9975  Earthquake   26.50
# 23389  12/18/2016  05:46:25  -10.2137   161.2177  Earthquake   37.39
# 23390  12/18/2016  06:15:46  -34.9886  -107.8694  Earthquake   10.00
# 23391  12/18/2016  06:39:42   -6.3046   154.3530  Earthquake   10.00
# 23392  12/18/2016  09:47:05    8.3489   137.6672  Earthquake   12.43
# 23393  12/18/2016  11:35:48  -10.1904   161.2187  Earthquake   57.52
# 23394  12/18/2016  13:30:11   -9.9640   -70.9714  Earthquake  622.54
# 23395  12/20/2016  04:21:29  -10.1773   161.2236  Earthquake   16.65
# 23396  12/20/2016  10:04:39   37.1442    84.9583  Earthquake   10.00
# 23397  12/20/2016  12:33:14  -10.1785   160.9149  Earthquake   10.00
# 23398  12/20/2016  20:07:53  -10.1549   160.7816  Earthquake   10.38
# 23399  12/21/2016  00:17:15   -7.5082   127.9206  Earthquake  152.00
# 23400  12/21/2016  16:43:57   21.5036   145.4172  Earthquake   12.05
# 23401  12/24/2016  01:32:16   -5.2453   153.5754  Earthquake   35.00
# 23402  12/24/2016  03:58:55   -5.1460   153.5166  Earthquake   30.00
# 23403  12/25/2016  14:22:27  -43.4029   -73.9395  Earthquake   38.00
# 23404  12/25/2016  14:32:13  -43.4810   -74.4771  Earthquake   14.93
# 23405  12/27/2016  23:20:56   45.7192    26.5230  Earthquake   97.00
# 23406  12/28/2016  08:18:01   38.3754  -118.8977  Earthquake   10.80
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type  Magnitude Error                         ID  \
# 0            6.0             MW              NaN               ISCGEM860706
# 1            5.8             MW              NaN               ISCGEM860737
# 2            6.2             MW              NaN               ISCGEM860762
# 3            5.8             MW              NaN               ISCGEM860856
# 4            5.8             MW              NaN               ISCGEM860890
# 5            6.7             MW              NaN               ISCGEM860922
# 6            5.9             MW              NaN               ISCGEM861007
# 7            6.0             MW              NaN               ISCGEM861111
# 8            6.0             MW              NaN            ISCGEMSUP861125
# 9            5.8             MW              NaN               ISCGEM861148
# 10           5.9             MW              NaN               ISCGEM861155
# 11           8.2             MW              NaN               ISCGEM861299
# 12           5.5             MW              NaN               ISCGEM861461
# 13           5.6             MW              NaN               ISCGEM859136
# 14           6.0             MW              NaN               ISCGEM859164
# 15           6.1             MW              NaN               ISCGEM859200
# 16           8.7             MW              NaN  OFFICIAL19650204050122_30
# 17           6.0             MW              NaN            ISCGEMSUP859215
# 18           5.7             MW              NaN               ISCGEM859221
# 19           5.8             MW              NaN               ISCGEM859222
# 20           5.9             MW              NaN            ISCGEMSUP859230
# 21           5.9             MW              NaN               ISCGEM859231
# 22           5.7             MW              NaN               ISCGEM859233
# 23           5.7             MW              NaN            ISCGEMSUP859241
# 24           5.7             MW              NaN               ISCGEM859252
# 25           5.6             MW              NaN               ISCGEM859261
# 26           7.3             MW              NaN               ISCGEM859264
# 27           6.5             MW              NaN               ISCGEM859324
# 28           5.6             MW              NaN               ISCGEM859333
# 29           6.4             MW              NaN               ISCGEM859358
# ...          ...            ...              ...                        ...
# 23382        5.5            MWW              NaN                 US20008002
# 23383        6.0            MWW              NaN                 US200080M3
# 23384        5.5            MWW              NaN                 US200080TD
# 23385        5.5            MWW              NaN                 US2000819R
# 23386        7.9            MWW              NaN                 US200081V8
# 23387        5.6             MB            0.066                 US200081VZ
# 23388        6.3            MWW              NaN                 US200081W0
# 23389        5.9            MWW              NaN                 US2000825R
# 23390        5.5            MWB            0.110                 US2000826E
# 23391        5.9            MWW              NaN                 US2000826M
# 23392        6.2            MWW              NaN                 US2000828L
# 23393        5.5             MB            0.048                 US20008293
# 23394        6.4            MWW              NaN                 US200082AN
# 23395        6.4            MWW              NaN                 US200082PP
# 23396        5.6            MWW              NaN                 US200082S5
# 23397        6.0            MWW              NaN                 US200082TK
# 23398        5.5            MWB            0.048                 US10007LIX
# 23399        6.7            MWW              NaN                 US10007LKW
# 23400        5.9            MWW              NaN                 US10007LQE
# 23401        6.0            MWW              NaN                 US10007MF5
# 23402        5.8            MWW              NaN                 US10007MFP
# 23403        7.6            MWW              NaN                 US10007MN3
# 23404        5.6             MB            0.067                 US10007MNB
# 23405        5.6            MWW              NaN                 US10007N3R
# 23406        5.6             ML            0.350                 NN00570709
# 23407        5.6             ML            0.320                 NN00570710
# 23408        5.5             ML            0.260                 NN00570744
# 23409        5.9            MWW              NaN                 US10007NAF
# 23410        6.3            MWW              NaN                 US10007NL0
# 23411        5.5             MB            0.029                 US10007NTD
#
#           Source Location Source Magnitude Source     Status Hemisferio
# 0         ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 1         ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 2         ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 3         ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 4         ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 5         ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 6         ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 7         ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 8      ISCGEMSUP          ISCGEM           ISCGEM  Automatic        Sul
# 9         ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 10        ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 11        ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 12        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 13        ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 14        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 15        ISCGEM          ISCGEM           ISCGEM  Automatic        Sul
# 16      OFFICIAL          ISCGEM         OFFICIAL  Automatic      Norte
# 17     ISCGEMSUP          ISCGEM           ISCGEM  Automatic      Norte
# 18        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 19        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 20     ISCGEMSUP          ISCGEM           ISCGEM  Automatic      Norte
# 21        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 22        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 23     ISCGEMSUP          ISCGEM           ISCGEM  Automatic      Norte
# 24        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 25        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 26        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 27        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 28        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# 29        ISCGEM          ISCGEM           ISCGEM  Automatic      Norte
# ...          ...             ...              ...        ...        ...
# 23382         US              US               US   Reviewed        Sul
# 23383         US              US               US   Reviewed      Norte
# 23384         US              US               US   Reviewed      Norte
# 23385         US              US               US   Reviewed      Norte
# 23386         US              US               US   Reviewed        Sul
# 23387         US              US               US   Reviewed        Sul
# 23388         US              US               US   Reviewed        Sul
# 23389         US              US               US   Reviewed        Sul
# 23390         US              US               US   Reviewed        Sul
# 23391         US              US               US   Reviewed        Sul
# 23392         US              US               US   Reviewed      Norte
# 23393         US              US               US   Reviewed        Sul
# 23394         US              US               US   Reviewed        Sul
# 23395         US              US               US   Reviewed        Sul
# 23396         US              US               US   Reviewed      Norte
# 23397         US              US               US   Reviewed        Sul
# 23398         US              US               US   Reviewed        Sul
# 23399         US              US               US   Reviewed        Sul
# 23400         US              US               US   Reviewed      Norte
# 23401         US              US               US   Reviewed        Sul
# 23402         US              US               US   Reviewed        Sul
# 23403         US              US               US   Reviewed        Sul
# 23404         US              US               US   Reviewed        Sul
# 23405         US              US               US   Reviewed      Norte
# 23406         NN              NN               NN   Reviewed      Norte
# 23407         NN              NN               NN   Reviewed      Norte
# 23408         NN              NN               NN   Reviewed      Norte
# 23409         US              US               US   Reviewed      Norte
# 23410         US              US               US   Reviewed        Sul
# 23411         US              US               US   Reviewed      Norte
#
# [23412 rows x 15 columns]

# %% [markdown]
# ## Q2 - Fit e Histograma
#
# Faça o Histograma da Magnitude. Interprete.

# %%
hist = plt.hist(df.Magnitude,normed = False,color= 'blue')
plt.ylim(0,15000)
plt.xlim(5.5,8.1)
plt.ylabel("Numero de Terremotos")
plt.ylabel('Numero de Terremotos')
plt.xlabel("Magnitude dos Terremotos")
plt.title("Magnitude")

# %% [markdown]
# Pela analise do histograma podemos notar que terremotos de Magnitude inferiores a 6.5 são muito mais comuns que terremotos de magnitudes superiores a 6.5.

# %% [markdown]
# Faça o fit de uma distribuição exponencial sobre os dados da Magnitude, achando os valores de **loc** e **scale**. Interprete loc e scale no caso da exponencial.
# Documentação: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html

# %%
mu, sigma = expon.fit(df.Magnitude)
print(mu, sigma)
# Out:
# 5.49999999967 0.382548648851

# %% [markdown]
# Refaça o Histograma plotando a fdp (função densidade de probabilidade) da exponencial com os parâmetros achados no fit em cima. Cuidado com o domínio utilizado. Interprete.

# %%
plt.plot(sorted(df.Magnitude), stats.norm.pdf(sorted(df.Magnitude), loc = mu, scale = sigma))

# %% [markdown]
# ## Q3 - Tabela cruzada
#
# Faça uma tabela de cruzamento das variáveis `Hemisfério` e `Type`
#
# Sua tabela deve ser <font color=red> normalizada</font>

# %%
HemiXType = pd.crosstab(df.Hemisferio,df.Type,normalize = True)
HemiXType

# %% [markdown]
# ### Q3.1 - Qual a probabilidade de ocorrer um terremoto no hemisfério norte?

# %% [markdown]
# Adicione na célula abaixo o cálculo:

# %%
prob = (10469/23232)*100 #sem normalizaçao 
prob2 = (0.447164/(0.447164+0.545148))*100 #com normalizaçao 
print('a probabilidade de ocorrer um terremoto é de {0}%'.format(prob2))# é esperado o mesmo resultado tanto para o prob um quanto para o prob2.

# %% [markdown]
# Explique o seu raciocínio

# %% [markdown]
# Para o calculo da probabilidade nos pegamos o caso estudado no caso o numero de terremotos no hemisferio norte(10469) e dividimos pelo nosso espaço amostral(23232).

# %% [markdown]
# ### Q3.2 - Dado que aconteceu no Norte, qual a probabilidade de ele ter sido `Nuclear Explosion`?

# %% [markdown]
# Calcule a resposta abaixo, ou explique como a encontrou

# %% [markdown]
# Se for cálculo preencha a célula a seguir:

# %%
num_Norte = df.Hemisferio.value_counts("Norte")
num_Norte
#Norte = 10618 / 0.453528
nuke = (0.006279/0.453528)*100
print('A probabilidade de ser uma "Nuclear Explosion" é de {0}%'.format(nuke))

# %% [markdown]
# Se conseguir obter a resposta sem calcular, insira a resposta abaixo:
#
# * A probabilidade de ter sido `Nuclear Explosion` é ...

# %% [markdown]
# ## Q4 - Análise bivariada
#
# Faça o *plot* de dispersão (*scatter plot*) entre as variáveis `Magnitude Error`  e `Depth`

# %%
plt.scatter(df["Magnitude Error"],df["Depth"])

# %% [markdown]
# Calcule a correlação entre as variáveis `Magnitude Error`  e `Depth`

# %%
df["Magnitude Error"].corr(df["Depth"])

# %% [markdown]
# Explique o que significa o valor da correlação calculada acima?

# %% [markdown]
# Este valor de correlação indica que as duas variaveis estão com pouca relaçao entre elas isto é nao posuem uma forte relaçao de causa e efeito. Logo podemons concluir que o erro na magnitude nao influencia muito a profundidade do terremoto.

# %% [markdown]
# ## Q5 - Describe e boxplot
#
# Faça o `describe` e o *boxplot* da `Latitude` e da `Longitude`. Explique os valores

# %%
#Longitude:
df["Longitude"].describe()

# %%
df.boxplot(column = "Longitude")

# %%
#Latitude
df["Latitude"].describe()

# %%
df.boxplot(column = "Latitude")

# %% [markdown]
# count seria o nosso total estudado, mean é a nossa media, std seria nosso desvio padrão, min e max seriao nossos valos minimos e maximos respectivamente, embaixo de min teriamos oas quantis sendo 25% nosso primeiro quantil, 50% mostrado pela linha verde no boxplot e 75% sendo nosso terceiro quantil. Os valores aqui representados fazem sentido pois a terra nao é uma esfera perfeita e nao houve terremotos em lugares exatos do globo exatamente em cima de nossas linhas de longitude e latitude.

# %% [markdown]
# ## Q6 - Tirando conclusões com base nos dados
#
# Em um certo lugar já ocorreram abalos com *Magnitude Type* `MB` e *Type* `Nuclear Explosion`.
#
# Responda:
#     * É mais provável que tenha sido no norte ou no sul?
#
# Assuma que os Magnitude Type e Type são independentes

# %%
pd.crosstab(df["Magnitude Type"],df["Type"])

# %%
pd.crosstab(df["Magnitude Type"],df["Hemisferio"])

# %%
pd.crosstab(df["Hemisferio"],df["Type"])

# %% [markdown]
# Seria mais provavel dizer que o evento occoreu no hemisferio norte devido ao numero de abalos sismicos por bombas nucleares ter sido em grande numero no hemisferio norte, logo é bem mais provavel um terremoto por bomba nuclear no hemisferio norte que no hemisferio sul.
